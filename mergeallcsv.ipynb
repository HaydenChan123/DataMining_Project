# %%
import pandas as pd
import glob

path = r'D:\Data_Acquisition\Unstructured_dataset' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame1 = pd.concat(li, axis=0, ignore_index=True)

# %%
frame1
# Out:
#                                               Heading
# 0   UK Prime Minister Boris Johnson and his Irish ...
# 1   Turkish ForeignMin: Turkey not responsible for...
# 2   AUD/USD technical analysis: Aussie easing from...
# 3   USD/JPY advances to session highs above 107.50...
# 4               EUR/NOK off 2-month highs above 10.08
# 5   US Dollar Index rebounds from lows near 98.70,...
# 6   GBP/USD technical analysis: Cable is trading n...
# 7   USD/CAD tracks the USD recovery, regains 1.330...
# 8            EUR/USD corrects lower, back near 1.1020
# 9   EUR/USD technical analysis: Euro hangs at thre...
# 10  Services sector remains healthy in New Zealand...
# 11  AUD/NZD: Remains undervalued despite last week...
# 12  AUD/USD Technical Analysis: Upside is likely t...
# 13          EUR/GBP drops to monthly lows near 0.8500
# 14  AUD/USD faces strong resistance near 0.6850 – UOB
# 15  GBP/JPY climbs further beyond 141.00 handle, f...
# ...

# %%
import pandas as pd
import glob

path = r'D:\Data_Acquisition\Unstructured_dataset\dec' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame2 = pd.concat(li, axis=0, ignore_index=True)

# %%
frame2
# Out:
#                                                Heading
# 0    EUR/USD ends November with a failed bear break...
# 1    GBP/USD Technical Analysis: Cable clings to we...
# 2    USD/JPY: The Japanese yen may take some guidan...
# 3    OPEC meeting could trigger higher volatility f...
# 4    AUD/USD Technical Analysis: Aussie on track to...
# 5    Eurozone week ahead: GDP, German Industrial Pr...
# 6    EUR/USD: The US dollar is well placed to stren...
# 7    USD/JPY pulls away from six-month highs, trade...
# 8    EUR/USD Technical Analysis: Euro bulls getting...
# 9    GBP/USD rebounds and rises back above 1.2900, ...
# 10   USD/JPY gains some traction amid improving ris...
# 11   USD/INR hits five-week lows sub-71.00 on risin...
# 12   When is the German ZEW survey and how could it...
# 13        GBP/USD: Facing key resistance – Commerzbank
# 14   AUD/USD holds above 0.6800 handle, lacks any m...
# 15   When are the UK data releases and how could th...
# ...

# %%
df=pd.concat([frame1, frame2], ignore_index=True)

# %%
df
# Out:
#                                                Heading
# 0    UK Prime Minister Boris Johnson and his Irish ...
# 1    Turkish ForeignMin: Turkey not responsible for...
# 2    AUD/USD technical analysis: Aussie easing from...
# 3    USD/JPY advances to session highs above 107.50...
# 4                EUR/NOK off 2-month highs above 10.08
# 5    US Dollar Index rebounds from lows near 98.70,...
# 6    GBP/USD technical analysis: Cable is trading n...
# 7    USD/CAD tracks the USD recovery, regains 1.330...
# 8             EUR/USD corrects lower, back near 1.1020
# 9    EUR/USD technical analysis: Euro hangs at thre...
# 10   Services sector remains healthy in New Zealand...
# 11   AUD/NZD: Remains undervalued despite last week...
# 12   AUD/USD Technical Analysis: Upside is likely t...
# 13           EUR/GBP drops to monthly lows near 0.8500
# 14   AUD/USD faces strong resistance near 0.6850 – UOB
# 15   GBP/JPY climbs further beyond 141.00 handle, f...
# ...

# %%
export_csv = df.to_csv (r'D:\Data_Acquisition\Unstructured_dataset\finalunstructureddata.csv', index = None, header=True)
